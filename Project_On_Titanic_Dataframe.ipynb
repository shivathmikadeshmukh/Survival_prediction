# %% [markdown]
# **IMPORTING ALL REQUIRED LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing csv file**

# %%
tt= pd.read_csv('/content/titanic.csv')

# %% [markdown]
# **to see first 5 rows**

# %%
tt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **displaying all statistical values**

# %%
tt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **information or data summary**

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#shape of data
tt.shape
# Out:
# (891, 12)

# %% [markdown]
# **Checking null values**

# %%
tt.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Removing null values and replacing missing values with central tendancies**

# %%
#age column
tt['Age'].fillna(np.mean(tt['Age']),inplace= True)

# %%
#Cabin
tt.drop('Cabin', axis=1,inplace= True)

# %%
#embarked
tt.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
tt['Embarked'].fillna('S', inplace=True)

# %%
tt.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# tt.head()

# %% [markdown]
# # Bar graph

# %%
sur = tt['Survived'].value_counts()
sur
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.bar(sur.index,sur.values, color = ['maroon', 'blue'])
plt.xlabel( 'Survived')
plt.ylabel('Count')
plt.show()

# %%
sex= tt.Sex.value_counts()
sex
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(sex.index,sex.values, color = ['skyblue', 'pink'])
plt.xlabel( 'Sex')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(tt.Age, bins = 10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
plt.hist(tt.Fare, color = 'Black')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Fare')
plt.show()

# %%
tt.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# # Pie Chart

# %%
p_class = tt.Pclass.value_counts()
p_class
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.pie(p_class.values, labels = p_class.index, autopct ='%1.1f%%', shadow=True, explode=(0.1,0.1,0.1),
       colors = ['red','pink','green'],
       wedgeprops={'edgecolor':'black',
                  'linewidth': 2})
plt.title('Pie chart for PClass')
plt.legend(title = '3 Class')
plt.show()

# %%
count_life = tt.Survived.value_counts()
count_life
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(count_life.values, labels = count_life.index, autopct='%1.1f%%', shadow = True, explode = (0.1,0.1),
        colors =['orange','brown'],
        wedgeprops = {'edgecolor' : 'black',
                     'linewidth' : 1.5})
plt.legend()
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(tt.Age, tt.Fare, color = 'orange')
plt.xlabel('Age of passenger')
plt.ylabel('Fare of Ticket')
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# # Box PLot

# %%
tt.boxplot('Age')
plt.show()

# %%
plt.boxplot(tt.Age)
plt.violinplot(tt.Age)
plt.show()

# %%
tt.boxplot('Fare')
plt.show()

# %% [markdown]
# # Sea Born

# %%
# Finding how many male and female survived
sns.set_style('whitegrid')
sns.countplot(x = 'Survived' , hue ='Sex', data = tt)
plt.show()

# %%
# Finding how many male and female survived from a particular class
sns.set_style('darkgrid')
sns.countplot(x = 'Survived' , hue ='Pclass', data = tt)
plt.show()

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = tt)
plt.xlabel("Passenger Class")
plt.ylabel("Age of passengers")
plt.show()

# %%
sns.violinplot(x ="Sex", y ="Age", hue ="Survived",
data = tt, split = True)
plt.xlabel("Sex")
plt.ylabel("Age of passengers")
plt.title('Sex and Age vs Survived')
plt.show()

# %%
sns.swarmplot(x = 'Pclass', y = 'Age', data = tt, hue = 'Pclass')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 30.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 38.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(tt, hue = 'Embarked')\
.map(plt.scatter, 'Age','Fare' )
plt.show()

# %%
sns.pairplot(tt, hue = 'Pclass')

# %% [markdown]
# # **Applying Machine Learning Algorithm**

# %%
from sklearn.preprocessing import LabelEncoder
encoded = LabelEncoder()
tt.Sex= encoded.fit_transform(tt.Sex)
tt.Embarked= encoded.fit_transform(tt.Embarked)

# %%
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %% [markdown]
#  **Splitting data into input and output**

# %%
x = tt[['Sex','Pclass','Age','Embarked']]
y = tt['Survived']

# %% [markdown]
#  **Split into test and train**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %% [markdown]
# **Applying Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 74.86033519553072

# %%
accuracies = []
accuracies.append(acc_score)

# %% [markdown]
#  **Applying Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 73.74301675977654

# %%
accuracies.append(acc_score)

# %% [markdown]
# **Applying Support Vector Machine(SVM)**

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 62.01117318435754

# %%
accuracies.append(acc_score)

# %% [markdown]
# **Applying KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 70.94972067039106

# %%
accuracies.append(acc_score)

# %% [markdown]
# **Applying Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 75.97765363128491

# %%
accuracies.append(acc_score)

# %% [markdown]
# **Applying Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 73.74301675977654

# %%
accuracies.append(acc_score)

# %%
classifiers = ['Logistic regression','Decision Tree','SVM', 'KNN','Naive Bayes','Random Forest']

# %% [markdown]
# **Visual representation of accuracies**

# %%
plt.barh(classifiers, accuracies, color = 'salmon')
plt.title('Accuracies of each classifiers')
plt.xlabel('Observed accuracy')
plt.ylabel('Classifiers')
plt.show()

# %% [markdown]
# # **Applying Hyper Parameter Tunning for KNN**

# %%
k_values = [1,2,3,4,5,6,7]
accuracies = []
for k in k_values:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracies.append(accuracy_score(y_test, y_pred))

# %%
accuracies
# Out:
# [0.664804469273743,
#  0.659217877094972,
#  0.6815642458100558,
#  0.6871508379888268,
#  0.7094972067039106,
#  0.6983240223463687,
#  0.6927374301675978]

# %%
#plotting k values versus accuracy
plt.figure(figsize=(4,4))
plt.plot(k_values, accuracies, color = 'red', linestyle = 'dashed',
        marker = '*', markerfacecolor = 'blue')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
